# %% [markdown]
# # Project Name :- INX Future Inc. Employee Performance Analysis.
# # Project Code :- 10281
# # --------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # CONTENT :
# ### The Project which is given here is an Employee Performance Analysis, which is a classification problem because the target variable consist of ordinal data.
# ### The given dataset consist of 1200 rows & 28 columns. The shape of the dataset is [1200x28].
# ### The 28 features are classified into Numerical and Categorical where 19 features are Numerical (11 columns consists numeric data & 8 columns consists ordinal data) and 8 features are Categorical.
# ### EmpNumber consist alphanumerical data (distinct values) which doesn't play a role as a relevant feature for performance rating, thats why we encode it into simple numbers.
# ### From Correlation the important aspects of the data correlation between features and Performance Rating.
# ### Correlation is a statistical measure that expresses the extent to which two variables are linearly related.The analysis of the project has gone through the stage of Univariate,Bivariate & Multivariate analysis, correlation analysis and analysis by each department to satisfy the project goal.
# # --------------------------------------------------------------------------------------------------------------
# # OBJECTIVE : Based On Given Features Of Dataset We Need To Predict The       Perfomance Rating of Employee.
# # --------------------------------------------------------------------------------------------------------------
#
# ### The Main Goal And Insight Of The Project Are As Follows, (As Per Guidelines) :-
# #### 1) Department Wise Performances.
# #### 2) Top 3 Important Factor effecting the employee performance.
# #### 3) A trained model which can predict the employee performance based on factors as inputs. This will be used to hire employees
# #### 4) Recommendations to improve the employee performance based on insights from analysis.
#
# ### In this Project 4 Machine Learning Algorithm are used,
#
# #### 1) Random Forest Classifier (With Hyperparameter Tuning)
# #### 2) Logistic Regression (With Hyperparameter Tuning)
# #### 3) Support Vector Classifier
# #### 4) Decision Tree
# ### From all above models Random Forest Classifier (With Hyperparameter Tuning) predicts higher accuracy 97.62%.
#
# ### One Of the important goal of the project is to find the important features affecting the preformance rating . The Important features were predicted using the machine learning model feature important technique.
#
# ### The Main Preprocessing technique is used Label Encoding- Convert Categorical Data into Numerical data.
#
# ### Most of machine learning algorithim are based on numerical methods where categorical data are not supportive.
#
# ### The overall project was performed and achieved the goals by using the machine learning model and visualization techniques.
# # --------------------------------------------------------------------------------------------------------------
#
# ## Requirement :-
#
# #### The data was given from the IABAC for this project where the collected source is IABAC™. The data is based on INX Future Inc.
#
# #### It is one of the leading data analytics and automation solutions provider with over 15 years of global business presence. INX is consistently rated as top 20 best employers past 5 years. The data is not from the real organization.
#
# #### The whole project was done in Jupiter notebook with python platform.
# # --------------------------------------------------------------------------------------------------------------
#
# ## Analysis :-
#
# #### As Below data were analyzed by describing the features present in the data.
#
# #### The features play the bigger part in the analysis.The features tell the relation between the dependent and independent variables.
#
# #### Pandas also help to describe the datasets answering following questions early in our project. The data present in the dataset are divided into numerical and categorical features.
#
# ### Numerical Features
#
# #### 1) Age : Age of employee in years
# #### 2) DistanceFromHome : Distance between home to company of employee
# #### 3) EmpHourlyRate : Hourly Rate means the amount paid to an employee for each hour worked.
# #### 4) NumCompaniesWorked :  Employee work in how many companies
# #### 5) EmpLastSalaryHikePercent : Salary hike percent of employee in last year.
# #### 6) TotalWorkExperienceInYears : Total experiance of employee in years.
# #### 7) TrainingTimesLastYear : Total training done by employee in last year.
# #### 8) ExperienceYearsAtThisCompany :  Total no of eaxperiance at current company.
# #### 9) ExperienceYearsInCurrentRole : Total no of experiance in current job role.
# #### 10) YearsSinceLastPromotion :  Total no of year since last promotion of employee.
# #### 11) YearsWithCurrManage :  Employee total no of years with current manager.
#
# ### Categorical Features
#
# #### 1) EmpNumber : An Employee ID, sometimes referred to as an Employee Number or Employee Code, is a unique number that has been assigned to each individual staff member within a company
# #### 2) Gender : Males and Females present in this Dataset
# ### 3) EducationBackground : This will be a high school diploma or a post-secondary degree of a employee.
# #### 4) MaritalStatus : Marital status, are the distinct options that describe a person's relationship with a significant other.
# #### 5) EmpDepartment : Department specifice of employee.
# #### 6) EmpJobRole : Job role means the key responsibility of a job profile or job position.
# #### 7) BusinessTravelFrequency : The employee travel for comapny buisness purpose.
# #### 8) OverTime :  Employee work overtime or not. [Yes, No]
# #### 9) Attrition : Employee attrition is the naturally occurring, voluntary departure of employees from a company. Employee attrition involves leaving a job for: Personal reasons. Professional motivation.
#
# ### Ordinal Features
#
# #### 1) EmpEducationLevel : ob levels, also known as job grades and classifications, set the responsibility level and expectations.
# #### 2) EmpEnvironmentSatisfaction : Satisfied employees are with elements like their jobs, their employee experience, and the organizations they work for.
# #### 3) EmpJobInvolvement : Job involvement refers to a state of psychological identification with work or the degree to which a job is central to a person's identity. From an organizational perspective, it has been regarded as the key to unlocking employee motivation and increasing productivity.
# #### 4) EmpJobLevel : Job levels, also known as job grades and classifications, set the responsibility level and expectations.
# #### 5) EmpJobSatisfaction : Level of contentment employees feel with their job.
# #### 6) EmpRelationshipSatisfaction :  Healthy relationships may motivate employees and increase morale. When employees cast aside relationship issues, they can focus on work tasks more effectively.
# #### 7) EmpWorkLifeBalance : “Work-life balance” typically means the achievement by employees of equality between time spent working and personal life. A good work-life balance for employees can improve staff motivation, increase staff retention rates, reduce absence, attract new talent, and reduce employee stress.
# #### 8) PerformanceRating :  This is a target variable,which tell that the total rating of employee performance in company.
# # --------------------------------------------------------------------------------------------------------------
# ## Explotary Data Analysis (EDA) :-
# #### In this we do basic checks and statistical measures to check that their is no constant feature/column is present in numerical as well as categorical data.
#
# #### EDA is Divided into Two parts :-
# #### 1) Univariate Analysis
# #### 2) Bivariate Analysis
#
# #### Univariate Analysis :- In univariate analysis we check the relationship of single features with count.
#
# #### Bivariate Analysis :-  In bivariate analysis we check the relationship between Two or more features.
# # --------------------------------------------------------------------------------------------------------------
#
# ## Data Pre- Processing :-
#
# #### In this we do some important pre- processing like,
#
# #### 1) Missing Values = Their is no missing values in this dataset.
# #### 2) Duplicate Values = Their is no zero duplicate value in this dataset.
# #### 3) Categorical to Numerical Conversion = For this we there are various method but in this dataset Label Enocding is much suited.
#
# ### Label Encoding :  Label encoding is a technique in machine learning that assigns unique numerical values to categorical data for model compatibility.
# # --------------------------------------------------------------------------------------------------------------
# ## Features Selection :-
# #### 1) Correlation = Checking correlation with the help of heat map, and get the their is no highly correlated feature is present.
#
# ### Heat Map = A heat map is a visual representation of data, using color intensity to show patterns, correlations, or variations in a matrix or grid-like format.
#   #### =>> Darker Color shows Positive correlation.
#   #### =>> Lighter color shows Negative correaltion.
#
# #### 2) Checks Duplicated Values = Their is no duplicated values
# #### 3) Drop Unique Featues = Their is no need for dropping the features because we do label encoding in this data set that convet all categorical data into numerical data.
# # --------------------------------------------------------------------------------------------------------------
# ## Model Creation And Evaluation :-
#
# #### 1) Splitting the data into Independet and Dependent variables (x & y).
# #### 2) Balancing is not needed in this data set because the is no imbalance data present in this dataset.
# #### 3) Appling Machine Learning Algorithms which are as mention below
#   #### =>> Random Forest Classifier (With Hyperparameter Tuning) = A Random Forest Classifier, with hyperparameter tuning, is an ensemble learning algorithm that combines multiple decision trees, optimizing parameters for improved predictive accuracy in machine learning tasks. It give the accuracy of 97.62 %
#   #### =>> Logistic Regression (With Hyperparameter Tuning) = Logistic Regression, with hyperparameter tuning, is a classification algorithm that optimizes parameters like regularization strength to enhance its predictive performance in machine learning applications. It give st he acuracy of 79.63 %.
#   #### =>>  Support Vector Classifier = A Support Vector Classifier (SVC) is a supervised machine learning algorithm that finds an optimal hyperplane to separate data into distinct classes while maximizing the margin between them . It gives the accuracy of 72.62 %
#   #### =>>  Decision Tree = A Decision Tree is a machine learning algorithm that partitions data into subsets based on feature values, forming a tree-like structure to make decisions or predictions at leaf nodes. It gives the accuracy of 72.62 %
#
# #### As we see that Random Forest Classifier  with appling Hyperparameter tuning gives best accuracy score as compare to others algorithms.
# #### So we select Random Forest Classifier.
# # --------------------------------------------------------------------------------------------------------------
#
# ### According to the Projetc Scenario, There are Some important objectives regarding this project ,
#
# ### 1) Department Wise Performances (Shown in Dataset) :-
#
# #### =>> Sales: The male performance rating is little bit higher compared to female.
#
# #### =>> Human Resources: In this both mail and females are less as compare to others departments
#
# #### =>> Development: Employees of all age are performing. The gender-based performance is nearly same for both.
#
# #### =>> Data Science: Data science is the only department where very less number of performers. All ages group of employees are working in this Department but in very less count.
#
# #### =>> Research & Development: The age factor is not deviating from the level of performance here where different employees with different age are there in every level of performance. The R&D has the good mele employees in their performance and also female employees
#
# #### =>> Finance: The finance department performance is exponentially decreasing when age increases.The male employees are doing good. The experience factor is inversely relating to the performance level.
#
# ### 2) Top 3 Important Factors effecting Employee Performance :-
#
# #### The top three important features affecting the performance rating are ordered with their importance level as follows,
#
# #### =>> Employment Environment Satisfaction = Maximum Number of Employees Performance Rating belongs to EmpEnvironmentSatisfaction Level 3 & Level 4.
# #### =>> Employee Salary Hike Percentage = More Number of Employees whose salary hike percentage belongs to 11-19 % are getting 2 & 3 performance rating Maximum time as well as Employees whose salary hike percentage is in between 20-22%, There performance rating is 4
# #### =>> Experience Years In CurrentRole = In EmpWorkLifeBalance, level 3 is showing high Performance Rating of employees.
#
# ### 3) A Trained model which can predict the Employee Performance :-
#
# #### The trained model is created using the machine learning algorithm as follows with the accuracy score,
#
# ##### 1) Random Forest Classifier (With Hyperparameter Tuning)=>>[97.62%]
# ##### 2) Logistic Regression (With Hyperparameter Tuning)=>>79.63%]
# ##### 3) Support Vector Classifier=>>[72.62%]
# ##### 4) Decision Tree=>>[72.62%]
#
#
# ### 4) Recommendations to improve the Employee Performance :-
#
# #### =>> The overall employee performance can be achieved by employee environment satisfaction. The company needs to focus more on the employee environment satisfaction.
# #### =>> The salary hike will give the boost to the employees to perform well.
# #### =>> Promote the employee ervery 6th month
# #### =>> Improve Employee's work-life balance this affects the performance rating.
# #### =>> While recruiting for HR, consider the female candidates where they perform well compared to male.
# #### =>> The development and sales department is having an overall higher performance comparing to rest of the departments. While some of the employees who gives feedback like Low & Medium from Job Satisfaction & Relationship Satisfaction feature, such employees gives Excellent performance more in number. So company should focus on them.
#
# # --------------------------------------------------------------------------------------------------------------
# ## Conclusion :-
# ### By observing the results, I came to a conclusion that Random Forest Classifier gives better accuracy score as compare to other model i,e. 97.62% which is far better than others algorithms. And its mean squared error is 0.069  which is very less because less error means its a generlized working model.
