# %% [markdown]
# # Project Name :- INX Future Inc. Employee Performance Analysis.
# # Project Code :- 10281
# # --------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## EDA stands for Exploratory Data Analysis. It's a crucial initial step in data analysis, involving the examination and visualization of data to discover patterns, anomalies and insights.

# %% [markdown]
# ## IMPORT ALL IMPORTANT LIBRARIES :-

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from matplotlib import rcParams

# %% [markdown]
# ## READING THE DATASET :-

# %%
data=pd.read_excel("Original_data.xls")

# %%
data.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 0                  3  ...                            4
# ...

# %% [markdown]
# ### We need to retrive the data from the original dataset

# %% [markdown]
# ## BASIC CHECKS :-

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   EmpNumber                     1200 non-null   object
#  1   Age                           1200 non-null   int64
#  2   Gender                        1200 non-null   object
#  3   EducationBackground           1200 non-null   object
#  4   MaritalStatus                 1200 non-null   object
#  5   EmpDepartment                 1200 non-null   object
#  6   EmpJobRole                    1200 non-null   object
#  7   BusinessTravelFrequency       1200 non-null   object
#  8   DistanceFromHome              1200 non-null   int64
#  9   EmpEducationLevel             1200 non-null   int64
#  10  EmpEnvironmentSatisfaction    1200 non-null   int64
#  11  EmpHourlyRate                 1200 non-null   int64
# ...

# %% [markdown]
# ### As we see there are total 28 features including Target Variables i,e Performance Rating.

# %%
data.isnull().sum()
# Out:
# EmpNumber                       0
# Age                             0
# Gender                          0
# EducationBackground             0
# MaritalStatus                   0
# EmpDepartment                   0
# EmpJobRole                      0
# BusinessTravelFrequency         0
# DistanceFromHome                0
# EmpEducationLevel               0
# EmpEnvironmentSatisfaction      0
# EmpHourlyRate                   0
# EmpJobInvolvement               0
# EmpJobLevel                     0
# EmpJobSatisfaction              0
# NumCompaniesWorked              0
# OverTime                        0
# EmpLastSalaryHikePercent        0
# EmpRelationshipSatisfaction     0
# TotalWorkExperienceInYears      0
# TrainingTimesLastYear           0
# EmpWorkLifeBalance              0
# ExperienceYearsAtThisCompany    0
# ExperienceYearsInCurrentRole    0
# YearsSinceLastPromotion         0
# YearsWithCurrManager            0
# Attrition                       0
# ...

# %% [markdown]
# ## As we see their is no null value present in this dataset.

# %%
data.describe()
# Out:
#                Age  DistanceFromHome  EmpEducationLevel  \
# count  1200.000000       1200.000000         1200.00000
# mean     36.918333          9.165833            2.89250
# std       9.087289          8.176636            1.04412
# min      18.000000          1.000000            1.00000
# 25%      30.000000          2.000000            2.00000
# 50%      36.000000          7.000000            3.00000
# 75%      43.000000         14.000000            4.00000
# max      60.000000         29.000000            5.00000
#
#        EmpEnvironmentSatisfaction  EmpHourlyRate  EmpJobInvolvement  \
# count                 1200.000000    1200.000000        1200.000000
# mean                     2.715833      65.981667           2.731667
# std                      1.090599      20.211302           0.707164
# min                      1.000000      30.000000           1.000000
# 25%                      2.000000      48.000000           2.000000
# ...

# %% [markdown]
# ## Here we clearly see that mean fo all features and the maximum and minimum values of each features present in this dataset.

# %%
print("EmpNumber :",data.EmpNumber.value_counts(),sep = '\n')
print("*"*40)
print("Gender :",data.Gender.value_counts(),sep = '\n')
print("*"*40)
print("EducationBackground :",data.EducationBackground.value_counts(),sep = '\n')
print("*"*40)
print("MaritalStatus :",data.MaritalStatus.value_counts(),sep = '\n')
print("*"*40)
print("EmpDepartment :",data.EmpDepartment.value_counts(),sep = '\n')
print("*"*40)
print("EmpJobRole :",data.EmpJobRole.value_counts(),sep = '\n')
print("*"*40)
print("BusinessTravelFrequency:",data.BusinessTravelFrequency.value_counts(),sep = '\n')
print("*"*40)
print("OverTime :",data.OverTime.value_counts(),sep = '\n')
print("*"*40)
print("PerformanceRating:",data.PerformanceRating.value_counts(),sep = '\n')
print("*"*40)
print("Attrition:",data.Attrition.value_counts(),sep = '\n')
print("*"*40)
# Out:
# EmpNumber :
# E1001000    1
# E100346     1
# E100342     1
# E100341     1
# E100340     1
#            ..
# E1001718    1
# E1001717    1
# E1001716    1
# E1001713    1
# E100998     1
# Name: EmpNumber, Length: 1200, dtype: int64
# ****************************************
# Gender :
# Male      725
# Female    475
# Name: Gender, dtype: int64
# ****************************************
# EducationBackground :
# Life Sciences       492
# Medical             384
# Marketing           137
# Technical Degree    100
# Other                66
# Human Resources      21
# Name: EducationBackground, dtype: int64
# ****************************************
# MaritalStatus :
# Married     548
# Single      384
# Divorced    268
# Name: MaritalStatus, dtype: int64
# ****************************************
# EmpDepartment :
# Sales                     373
# Development               361
# Research & Development    343
# Human Resources            54
# Finance                    49
# ...

# %% [markdown]
# ## In EDA we use two different analysis :-
# ### 1) Univariate Analysis = >> Univariate analysis is the statistical analysis of a single variable in isolation, examining its distribution, summary statistics, and characteristics without considering relationships with other variables.
# ### 2) Bivariate Analysis =>> Bivariate analysis is a statistical analysis that focuses on the relationship between two variables, exploring how they interact or influence each other to uncover patterns and insights in data.

# %% [markdown]
# ## Relationship between  Age & Gender :-

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='Age',data= data,hue='Gender')
plt.xlabel('Age',fontsize=15)
plt.ylabel('Gender',fontsize=20)
plt.title('Age Vs Gender',fontsize=20)
plt.show()

# %% [markdown]
# ### This plot shows what are the numbers of  Male and Females are present in Age (columns).

# %%
G=data['Gender'].value_counts()

# %%
G
# Out:
# Male      725
# Female    475
# Name: Gender, dtype: int64

# %%
rcParams['figure.figsize']=5,5
plt.pie(G,[0,0],colors=['red','blue'],labels=['MALES','FEMALES'],autopct='%1.0f%%')
plt.title('Males Vs Females',fontsize=20)
plt.show()

# %% [markdown]
# ### 60% Males & 40% Females are present in the Age Group betweem 18 to 60 year old.

# %%
Edu=data['EducationBackground'].value_counts()

# %%
Edu
# Out:
# Life Sciences       492
# Medical             384
# Marketing           137
# Technical Degree    100
# Other                66
# Human Resources      21
# Name: EducationBackground, dtype: int64

# %%
rcParams['figure.figsize']=5,5
plt.pie(Edu,[0,0,0,0,0,0],colors=['red','blue','green','pink','yellow','orange'],labels=['Life Sciences','Medical','Marketing','Technical Degree','Other','Human Resources'],autopct='%1.0f%%')
plt.title('Education Background',fontsize=20)
plt.show()

# %% [markdown]
# ### As we see clearly in this pie chart that maximum numbers employees come from Life Science Education Background and 32% comes from Medical Background .Only 2% employees come from Human Resources background.

# %%
MS=data['MaritalStatus'].value_counts()

# %%
MS
# Out:
# Married     548
# Single      384
# Divorced    268
# Name: MaritalStatus, dtype: int64

# %%
rcParams['figure.figsize']=5,5
plt.pie(MS,[0,0,0],colors=['green','pink','yellow'],labels=['Married','Single','Divorced'],autopct='%1.0f%%')
plt.title('Marital Status',fontsize=20)
plt.show()

# %% [markdown]
# ### In this company 46% employees are Married & 32% are Single and 22% are Divorced Employees.According to this Survey we clearly understand that company has a clear motive of supporting the employee martial Status.

# %%
ED=data['EmpDepartment'].value_counts()

# %%
ED
# Out:
# Sales                     373
# Development               361
# Research & Development    343
# Human Resources            54
# Finance                    49
# Data Science               20
# Name: EmpDepartment, dtype: int64

# %%
rcParams['figure.figsize']=5,5
plt.pie(ED,colors=['green','pink','yellow','red','orange','blue'],labels=['Sales', 'Development', 'Research & Development', 'Human Resources', 'Finance', 'Data Science'],autopct='%1.0f%%')
plt.title('Employee Department',fontsize=20)
plt.show()

# %% [markdown]
# ###  In this company maximum nubers of employees present in Sales after that in Development Department. Datascience has 2% emloyees in their company.

# %%
ER=data['EmpJobRole'].value_counts()

# %%
ER
# Out:
# Sales Executive              270
# Developer                    236
# Manager R&D                   94
# Research Scientist            77
# Sales Representative          69
# Laboratory Technician         64
# Senior Developer              52
# Manager                       51
# Finance Manager               49
# Human Resources               45
# Technical Lead                38
# Manufacturing Director        33
# Healthcare Representative     33
# Data Scientist                20
# Research Director             19
# Business Analyst              16
# Senior Manager R&D            15
# Delivery Manager              12
# Technical Architect            7
# Name: EmpJobRole, dtype: int64

# %%
rcParams['figure.figsize']=10,10
plt.pie(ER,labels=['Sales Executive','Developer','Manager R&D','Research Scientist','Sales Representative','Laboratory Technician','Senior Developer','Manager','Finance Manager','Human Resources','Technical Lead','Manufacturing Director','Healthcare Representative','Data Scientist','Research Director','Business Analyst','Senior Manager R&D','Delivery Manager','Technical Architect'],autopct='%1.0f%%')
plt.title('Employee Job Role',fontsize=20)
plt.show()

# %% [markdown]
# ### As we see in this chart that this company has more numbers of Sales Executive  and 20% of Developers as compare to others job role present in company.Senior Manager R&D, Delivery Manager, technical Architech & Business Analyst are only 1% in this company because these are the high profile job which need very high qualifications and Experience.

# %%
BTF=data['BusinessTravelFrequency'].value_counts()

# %%
BTF
# Out:
# Travel_Rarely        846
# Travel_Frequently    222
# Non-Travel           132
# Name: BusinessTravelFrequency, dtype: int64

# %%
rcParams['figure.figsize']=5,5
plt.pie(BTF,[0,0,0],colors=['Red','Blue','Green'],labels=['Travel_Rarely','Travel_Frequently','Non-Travel'],autopct='%1.0f%%')
plt.title('Business Travel Frequency',fontsize=20)
plt.show()

# %% [markdown]
# ### Here we clearly understand that company has only Desk Job are compare to Non- Desk Job, because the 70% employee travel very rarely.

# %%
OT=data['OverTime'].value_counts()

# %%
OT
# Out:
# No     847
# Yes    353
# Name: OverTime, dtype: int64

# %%
rcParams['figure.figsize']=5,5
plt.pie(OT,[0,0],colors=['Pink','Green'],labels=['No','Yes'],autopct='%1.0f%%')
plt.title('Over Time',fontsize=20)
plt.show()

# %% [markdown]
# ### This Company has 71% of No overtime policy which is very good for those employees whose age is more than 50+.

# %%
ATT=data['Attrition'].value_counts()

# %%
ATT
# Out:
# No     1022
# Yes     178
# Name: Attrition, dtype: int64

# %%
rcParams['figure.figsize']=5,5
plt.pie(ATT,[0,0],colors=['Yellow','Blue'],labels=['No','Yes'],autopct='%1.0f%%')
plt.title('Attrition',fontsize=20)
plt.show()

# %% [markdown]
# ### Only 15 % employees left this company due to resignation, termination, death or retirement.

# %%
fig=plt.figure(figsize=(20,40))
plotnumber=1
for column in data.columns:
    plt.subplot(10,3,plotnumber)
    sns.histplot(x=column,data=data,kde=True,hue='PerformanceRating',color='Blue',bins=10)
    plotnumber+=1
plt.tight_layout()
plt.xlabel('column',fontsize= 30)
plt.show()

# %% [markdown]
# ### Here we clearly see all relations between Performance Rating and 27 Features which i clearly mention in above cell.
# ### Histplot is used to display all the subplots.
# ### Histplot =>> A histplot, short for "histogram plot," is a data visualization technique used in statistics and data analysis to represent the distribution of a single numerical variable. It displays the frequency or count of data points within predefined intervals (bins) as bars, providing insight into the data's underlying distribution and patterns.

# %% [markdown]
# ## CORRELATION :-
# ### 1)  Correlation is a statistical measure that quantifies the degree to which two or more variables are related or associated. It assesses the strength and direction of the relationship between variables.
# ### 2) Common correlation coefficients include Pearson's correlation coefficient (for linear relationships), Spearman's rank correlation coefficient (for monotonic relationships), and others.
# ### 3) A correlation value typically ranges from -1 (perfect negative correlation) to 1 (perfect positive correlation), with 0 indicating no linear correlation. Correlation does not imply causation; it only indicates a statistical association between variables.

# %%
data.corr()
# Out:
#                                    Age  DistanceFromHome  EmpEducationLevel  \
# Age                           1.000000          0.020937           0.207313
# DistanceFromHome              0.020937          1.000000           0.045856
# EmpEducationLevel             0.207313          0.045856           1.000000
# EmpEnvironmentSatisfaction    0.013814         -0.017719          -0.037103
# EmpHourlyRate                 0.062867          0.013730           0.014095
# EmpJobInvolvement             0.027216          0.003231           0.027544
# EmpJobLevel                   0.509139          0.017270           0.100734
# EmpJobSatisfaction           -0.002436         -0.003036           0.000357
# NumCompaniesWorked            0.284408         -0.021411           0.128674
# EmpLastSalaryHikePercent     -0.006105          0.044974           0.002358
# EmpRelationshipSatisfaction   0.049749         -0.009509          -0.016690
# ...

# %% [markdown]
# ### For Plotting Correlation we use HeatMap.
# ## HEAT MAP :-
# ### 1) A heat map is a graphical representation of data where values in a matrix are represented as colors. It is often used to visualize the magnitude of a variable in a two-dimensional dataset.
# ### 2) In a typical heat map, each cell in the matrix is assigned a color shades based on the value it represents.
# ### 3) Heat maps are useful for identifying patterns, trends, and correlations in complex datasets, especially when dealing with large amounts of numerical or categorical data. They are commonly used in various fields, including data analysis, biology, finance etc.

# %%
corr = data.corr()
plt.figure(figsize=(30,30))
sns.heatmap(corr, cmap ='Greens', annot= True)
plt.show()

# %% [markdown]
# ## CONCLUSION :-
# ### By Observation I came to a conclusion that the top three best features selected for analysis are 'EmpEnvironmentSatisfaction','EmpLastSalaryHikePercent','YearsSinceLastPromotion' with 'EmpDepartment' As they have high correlation with 'PerformanceRating'.
# ###  In this we used Correlation this is the important feature transformations which helps us to understand the which feature is highly correlated to which feature or target variables.
